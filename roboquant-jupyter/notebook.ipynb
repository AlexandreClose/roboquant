// %%
%use roboquant(version=3.0.0-SNAPSHOT)

import org.roboquant.kandy.PriceBarChartKandy

val kandyChart = PriceBarChartKandy(
    asset = Asset("AAPL"),
    feed = AvroFeed.sp25(),
    timeframe = Timeframe.fromYears(2010, 2016)
)

kandyChart.plot()
// Out:
// org.jetbrains.kotlinx.jupyter.exceptions.ReplCompilerException: at Cell In[4], line 7, column 13: Unresolved reference. None of the following candidates is applicable because of receiver type mismatch:
// public operator fun <T : SelfInvocationContext> TypeVariable(T).invoke(block: TypeVariable(T).() -> Unit): TypeVariable(T) defined in org.jetbrains.kotlinx.kandy.util.context
// public inline operator fun <reified T> String.invoke(): ColumnAccessor<TypeVariable(T)> defined in org.jetbrains.kotlinx.kandy.dsl
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.JupyterCompilerImpl.compileSync(JupyterCompilerImpl.kt:151)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.InternalEvaluatorImpl.eval(InternalEvaluatorImpl.kt:126)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.CellExecutorImpl.execute_L4Nmkdk$lambda$0$0(CellExecutorImpl.kt:80)
// 	at org.jetbrains.kotlinx.jupyter.repl.impl.ReplForJupyterImpl.withHost(ReplForJupyterImpl.kt:791)
// ...
